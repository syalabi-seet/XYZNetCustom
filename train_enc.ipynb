# %%
import os
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from src.dataset import *
from src.model import *

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
config = {
    'local_depth': 16,
    'local_convdepth': 32,
    'local_imagesize': 256,
    'global_depth': 5,
    'global_convdepth': 64,
    'global_imagesize': 128,
    'scale': 0.25}

model = CIEXYZNet(**config)
if os.path.exists("model_weights/model.index"):
    model.load_weights("model_weights/model")
# Out:
# 2022-06-04 09:42:28.710180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:28.735489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:28.735757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:28.736555: I tensorflow/core/platform/cpu_feature_guard.cc:152] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-04 09:42:28.738283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:28.738490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:28.738703: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:29.203647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:29.203931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:29.203945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-06-04 09:42:29.204191: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:938] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0d:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-04 09:42:29.204243: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21398 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0d:00.0, compute capability: 8.6

# %%
BATCH_SIZE = 4
EPOCHS = 200
LR = 1e-4

schedule = CosineDecayWithWarmup(
    epochs=EPOCHS,
    lr_max=1e-4,
    lr_min=1e-7,
    sustain_epochs=50)

schedule.plot()

xyz_loss_fn = MeanAbsoluteError()
optimizer = tf.keras.optimizers.Adam(schedule)
metric_fn = tf.keras.metrics.Mean()

train_dataset = DataLoader(train_set="training", batch_size=BATCH_SIZE)
val_dataset = DataLoader(train_set="validation", batch_size=BATCH_SIZE)
test_dataset = DataLoader(train_set="testing", batch_size=BATCH_SIZE)

train_steps = len(train_dataset)

# %%
history_path = "history/history.json"
if os.path.exists(history_path):
    with open(history_path, "r") as f:
        history = json.load(f)
    best_val = min(history['val_loss'])
else:
    history = {'loss': [], 'val_loss': []}
    best_val = np.inf

current_epoch = len(history['loss'])
for epoch in range(current_epoch+1, EPOCHS+1):
    print(f"Epoch {epoch}/{EPOCHS}")
    progbar = tf.keras.utils.Progbar(
        train_steps, interval=0.05,
        stateful_metrics=['loss', 'val_loss'])
    for step, train_batch in enumerate(train_dataset.data):
        sRGB_image = train_batch['sRGB_image']
        XYZ_image = train_batch['XYZ_image']
        with tf.GradientTape() as tape:
            train_logits = model(sRGB_image, training=True)
            train_loss = xyz_loss_fn(XYZ_image, train_logits) 

        grads = tape.gradient(train_loss, model.trainable_weights)
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        metric_fn.update_state(train_loss)
        train_mae = metric_fn.result().numpy()
        progbar.update(step, values=[('loss', train_mae)], finalize=False)
    
    metric_fn.reset_state()
    
    for val_batch in val_dataset.data:
        sRGB_image = val_batch['sRGB_image']
        XYZ_image = val_batch['XYZ_image']
        val_logits = model(sRGB_image)
        val_loss = xyz_loss_fn(XYZ_image, val_logits) 
        metric_fn.update_state(val_loss)

    val_mae = metric_fn.result().numpy()
    values = {'loss': train_mae, 'val_loss': val_mae}
    progbar.update(train_steps, values=values.items(), finalize=True)
    metric_fn.reset_state()

    history['loss'].append(np.float64(train_mae))
    history['val_loss'].append(np.float64(val_mae))

    with open(history_path, "w") as f:
        json.dump(history, f, indent=4)

    if best_val > val_mae:
        best_val = val_mae 
        model.save_weights("model_weights/model")
        print("Model improved and saved")
# Out:
# Epoch 6/200
# 2022-06-04 09:42:31.404693: I tensorflow/stream_executor/cuda/cuda_dnn.cc:379] Loaded cuDNN version 8400
# 2022-06-04 09:42:32.391339: I tensorflow/stream_executor/cuda/cuda_blas.cc:1804] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 242/242 [==============================] - 17s 61ms/step - loss: 0.0334 - val_loss: 0.0291
# Model improved and saved
# Epoch 7/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0320 - val_loss: 0.0284
# Model improved and saved
# Epoch 8/200
# 242/242 [==============================] - 15s 59ms/step - loss: 0.0307 - val_loss: 0.0289
# Epoch 9/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0300 - val_loss: 0.0290
# Epoch 10/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0292 - val_loss: 0.0293
# Epoch 11/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0291 - val_loss: 0.0269
# Model improved and saved
# Epoch 12/200
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0287 - val_loss: 0.0269
# Model improved and saved
# Epoch 13/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0286 - val_loss: 0.0268
# Model improved and saved
# Epoch 14/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0278 - val_loss: 0.0273
# Epoch 15/200
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0275 - val_loss: 0.0268
# Model improved and saved
# Epoch 16/200
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0275 - val_loss: 0.0262
# Model improved and saved
# Epoch 17/200
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0269 - val_loss: 0.0264
# Epoch 18/200
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0264 - val_loss: 0.0267
# Epoch 19/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0266 - val_loss: 0.0280
# Epoch 20/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0264 - val_loss: 0.0290
# Epoch 21/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0261 - val_loss: 0.0269
# Epoch 22/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0259 - val_loss: 0.0269
# Epoch 23/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0254 - val_loss: 0.0261
# Model improved and saved
# Epoch 24/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0254 - val_loss: 0.0262
# Epoch 25/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0256 - val_loss: 0.0272
# Epoch 26/200
# 242/242 [==============================] - 15s 60ms/step - loss: 0.0244 - val_loss: 0.0261
# Model improved and saved
# Epoch 27/200
# 237/242 [============================>.] - ETA: 0s - loss: 0.0248
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/lib/docker/volumes/XYZNet/train.ipynb Cell 4' in <cell line: 11>()
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f78797a6e6574227d/var/lib/docker/volumes/XYZNet/train.ipynb#ch0000003vscode-remote?line=17'>18</a> XYZ_image = train_batch['XYZ_image']
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f78797a6e6574227d/var/lib/docker/volumes/XYZNet/train.ipynb#ch0000003vscode-remote?line=18'>19</a> with tf.GradientTape() as tape:
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f78797a6e6574227d/var/lib/docker/volumes/XYZNet/train.ipynb#ch0000003vscode-remote?line=19'>20</a>     train_logits = model(sRGB_image, training=True)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f78797a6e6574227d/var/lib/docker/volumes/XYZNet/train.ipynb#ch0000003vscode-remote?line=20'>21</a>     train_loss = xyz_loss_fn(XYZ_image, train_logits)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f78797a6e6574227d/var/lib/docker/volumes/XYZNet/train.ipynb#ch0000003vscode-remote?line=22'>23</a> grads = tape.gradient(train_loss, model.trainable_weights)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1091'>1092</a>   inputs = self._maybe_cast_inputs(inputs, input_list)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1093'>1094</a> with autocast_variable.enable_auto_cast_variables(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1094'>1095</a>     self._compute_dtype_object):
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1095'>1096</a>   outputs = call_fn(inputs, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1097'>1098</a> if self._activity_regularizer:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1098'>1099</a>   self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=89'>90</a> bound_signature = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=90'>91</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=91'>92</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=92'>93</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=93'>94</a>   if hasattr(e, '_keras_call_info_injected'):
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=94'>95</a>     # Only inject info for the innermost failing call
#
# File /var/lib/docker/volumes/XYZNet/src/model.py:167, in CIEXYZNet.call(self, x)
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=165'>166</a> def call(self, x):
# --> <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=166'>167</a>     xyz = self.forward_srgb2xyz(x)
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=167'>168</a>     return xyz
#
# File /var/lib/docker/volumes/XYZNet/src/model.py:159, in CIEXYZNet.forward_srgb2xyz(self, srgb)
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=157'>158</a> def forward_srgb2xyz(self, srgb):
# --> <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=158'>159</a>     l_xyz = srgb - self.forward_local(srgb, target='xyz')
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=159'>160</a>     return self.forward_global(l_xyz, target='xyz')
#
# File /var/lib/docker/volumes/XYZNet/src/model.py:126, in CIEXYZNet.forward_local(self, x, target)
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=123'>124</a> def forward_local(self, x, target):
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=124'>125</a>     if target == "xyz":
# --> <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=125'>126</a>         x = self.srgb2xyz_localnet(x)
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=126'>127</a>     elif target == "srgb":
#     <a href='file:///var/lib/docker/volumes/XYZNet/src/model.py?line=127'>128</a>         x = self.xyz2srgb_localnet(x)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1091'>1092</a>   inputs = self._maybe_cast_inputs(inputs, input_list)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1093'>1094</a> with autocast_variable.enable_auto_cast_variables(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1094'>1095</a>     self._compute_dtype_object):
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1095'>1096</a>   outputs = call_fn(inputs, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1097'>1098</a> if self._activity_regularizer:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1098'>1099</a>   self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=89'>90</a> bound_signature = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=90'>91</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=91'>92</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=92'>93</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=93'>94</a>   if hasattr(e, '_keras_call_info_injected'):
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=94'>95</a>     # Only inject info for the innermost failing call
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py:374, in Sequential.call(self, inputs, training, mask)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=371'>372</a>   if not self.built:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=372'>373</a>     self._init_graph_network(self.inputs, self.outputs)
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=373'>374</a>   return super(Sequential, self).call(inputs, training=training, mask=mask)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=375'>376</a> outputs = inputs  # handle the corner case where self.layers is empty
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=376'>377</a> for layer in self.layers:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=377'>378</a>   # During each iteration, `inputs` are the inputs to `layer`, and `outputs`
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=378'>379</a>   # are the outputs of `layer` applied to `inputs`. At the end of each
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py?line=379'>380</a>   # iteration `inputs` is set to `outputs` to prepare for the next layer.
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:451, in Functional.call(self, inputs, training, mask)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=431'>432</a> @doc_controls.do_not_doc_inheritable
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=432'>433</a> def call(self, inputs, training=None, mask=None):
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=433'>434</a>   """Calls the model on new inputs.
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=434'>435</a>
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=435'>436</a>   In this case `call` just reapplies
#    (...)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=448'>449</a>       a list of tensors if there are more than one outputs.
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=449'>450</a>   """
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=450'>451</a>   return self._run_internal_graph(
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=451'>452</a>       inputs, training=training, mask=mask)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py:589, in Functional._run_internal_graph(self, inputs, training, mask)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=585'>586</a>   continue  # Node is not computable, try skipping.
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=587'>588</a> args, kwargs = node.map_arguments(tensor_dict)
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=588'>589</a> outputs = node.layer(*args, **kwargs)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=590'>591</a> # Update tensor_dict.
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/functional.py?line=591'>592</a> for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1091'>1092</a>   inputs = self._maybe_cast_inputs(inputs, input_list)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1093'>1094</a> with autocast_variable.enable_auto_cast_variables(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1094'>1095</a>     self._compute_dtype_object):
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1095'>1096</a>   outputs = call_fn(inputs, *args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1097'>1098</a> if self._activity_regularizer:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py?line=1098'>1099</a>   self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=89'>90</a> bound_signature = None
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=90'>91</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=91'>92</a>   return fn(*args, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=92'>93</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=93'>94</a>   if hasattr(e, '_keras_call_info_injected'):
#      <a href='file:///usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py?line=94'>95</a>     # Only inject info for the innermost failing call
#
# File /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py:248, in Conv.call(self, inputs)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=244'>245</a> if self._is_causal:  # Apply causal padding to inputs for Conv1D.
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=245'>246</a>   inputs = tf.pad(inputs, self._compute_causal_padding(inputs))
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=247'>248</a> outputs = self.convolution_op(inputs, self.kernel)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=249'>250</a> if self.use_bias:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=250'>251</a>   output_rank = outputs.shape.rank
#
# File /usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py:233, in Conv.convolution_op(self, inputs, kernel)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=229'>230</a> else:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=230'>231</a>   tf_padding = self.padding
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=232'>233</a> return tf.nn.convolution(
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=233'>234</a>     inputs,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=234'>235</a>     kernel,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=235'>236</a>     strides=list(self.strides),
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=236'>237</a>     padding=tf_padding,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=237'>238</a>     dilations=list(self.dilation_rate),
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=238'>239</a>     data_format=self._tf_data_format,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/keras/layers/convolutional.py?line=239'>240</a>     name=self.__class__.__name__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1079'>1080</a> # Fallback dispatch system (dispatch v1):
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1080'>1081</a> try:
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1081'>1082</a>   return dispatch_target(*args, **kwargs)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1082'>1083</a> except (TypeError, ValueError):
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1083'>1084</a>   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1084'>1085</a>   # TypeError, when given unexpected types.  So we need to catch both.
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py?line=1085'>1086</a>   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1148, in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1137'>1138</a> @tf_export("nn.convolution", v1=[])
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1138'>1139</a> @dispatch.add_dispatch_support
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1139'>1140</a> def convolution_v2(  # pylint: disable=missing-docstring
#    (...)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1145'>1146</a>     dilations=None,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1146'>1147</a>     name=None):
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1147'>1148</a>   return convolution_internal(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1148'>1149</a>       input,  # pylint: disable=redefined-builtin
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1149'>1150</a>       filters,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1150'>1151</a>       strides=strides,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1151'>1152</a>       padding=padding,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1152'>1153</a>       data_format=data_format,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1153'>1154</a>       dilations=dilations,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1154'>1155</a>       name=name)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:1280, in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1276'>1277</a>   else:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1277'>1278</a>     op = conv1d
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1279'>1280</a>   return op(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1280'>1281</a>       input,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1281'>1282</a>       filters,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1282'>1283</a>       strides,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1283'>1284</a>       padding=padding,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1284'>1285</a>       data_format=data_format,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1285'>1286</a>       dilations=dilations,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1286'>1287</a>       name=name)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1287'>1288</a> else:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=1288'>1289</a>   if channel_index == 1:
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py:2756, in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2751'>2752</a> input_rank = input.shape.rank
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2752'>2753</a> if input_rank is None or input_rank < 5:
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2753'>2754</a>   # We avoid calling squeeze_batch_dims to reduce extra python function
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2754'>2755</a>   # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2755'>2756</a>   return gen_nn_ops.conv2d(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2756'>2757</a>       input,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2757'>2758</a>       filter=filters,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2758'>2759</a>       strides=strides,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2759'>2760</a>       padding=padding,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2760'>2761</a>       data_format=data_format,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2761'>2762</a>       dilations=dilations,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2762'>2763</a>       name=name)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2763'>2764</a> return squeeze_batch_dims(
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2764'>2765</a>     input,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2765'>2766</a>     functools.partial(
#    (...)
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2772'>2773</a>     inner_rank=3,
#    <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py?line=2773'>2774</a>     name=name)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py:925, in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=922'>923</a> if tld.is_eager:
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=923'>924</a>   try:
# --> <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=924'>925</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=925'>926</a>       _ctx, "Conv2D", name, input, filter, "strides", strides,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=926'>927</a>       "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding", padding,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=927'>928</a>       "explicit_paddings", explicit_paddings, "data_format", data_format,
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=928'>929</a>       "dilations", dilations)
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=929'>930</a>     return _result
#     <a href='file:///usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_nn_ops.py?line=930'>931</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
history = pd.read_json("history/history.json", orient="column")
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.ylim(top=0.4, bottom=0)
plt.show()

# %%
for test_batch in test_dataset.data:
    sRGB_image = test_batch['sRGB_image']
    XYZ_image = test_batch['XYZ_image']
    test_logits = model(sRGB_image)
    test_loss = xyz_loss_fn(XYZ_image, test_logits)
    print(tf.reduce_max(test_logits))
    metric_fn.update_state(test_loss)

print("Test loss:", metric_fn.result().numpy())
# Out:
# tf.Tensor(0.56361914, shape=(), dtype=float32)
# tf.Tensor(0.6175503, shape=(), dtype=float32)
# tf.Tensor(0.66189057, shape=(), dtype=float32)
# tf.Tensor(0.64834887, shape=(), dtype=float32)
# tf.Tensor(0.6099959, shape=(), dtype=float32)
# tf.Tensor(0.62897253, shape=(), dtype=float32)
# tf.Tensor(0.72343093, shape=(), dtype=float32)
# tf.Tensor(0.62331426, shape=(), dtype=float32)
# tf.Tensor(0.6684493, shape=(), dtype=float32)
# tf.Tensor(0.6811198, shape=(), dtype=float32)
# tf.Tensor(0.5809463, shape=(), dtype=float32)
# tf.Tensor(0.6099899, shape=(), dtype=float32)
# tf.Tensor(0.71548384, shape=(), dtype=float32)
# Test loss: 0.025013212

# %%
test_batch = next(iter(test_dataset.data))
for i in range(len(test_batch['filename'])):
    test_logits = model(test_batch['sRGB_image'])
    print("Filename:", test_batch['filename'][i].numpy().decode())
    fig, ax = plt.subplots(1, 2, figsize=(10, 10))
    ax[0].imshow(test_batch['XYZ_image'][i].numpy())
    ax[1].imshow(test_logits[i].numpy())
    ax[0].set_title("True")
    ax[1].set_title("Predicted")
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Filename: a0877-_DGW6231.JPG
# Filename: a1292-_DSC0177.JPG
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Filename: a1669-NKIM_MG_7498.JPG
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Filename: a1468-IMG_5020.JPG
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
